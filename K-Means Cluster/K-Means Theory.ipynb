# %% [markdown]
# # Unsupervised  Machine Learning - K- Means Clustering

# %% [markdown]
# **Unsupervised learning** is a branch of machine learning that learns from test data that has not been labeled, classified or categorized. Instead of responding to feedback, unsupervised learning identifies commonalities in the data and reacts based on the presence or absence of such commonalities in each new piece of data.

# %% [markdown]
# ### Clustering

# %% [markdown]
# In clustering problems we split the training examples by unknown characteristics. The algorithm itself decides what characteristic to use for splitting.

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# **K-Means clustering** aims to partition n observations into K clusters in which each observation belongs to the cluster with the nearest mean, serving as a prototype of the cluster.
#
# The result of a cluster analysis shown below as the coloring of the squares into three clusters.
#
# ![image.png](attachment:image.png)

# %%
# Based on distance formula

# %% [markdown]
# ![ChessUrl](https://camo.githubusercontent.com/286fd8509cd5a58b0caea6ec264069d50295af09/687474703a2f2f73686162616c2e696e2f76697375616c732f6b6d65616e732f72616e646f6d2e676966)

# %%
# 2nd method

# %% [markdown]
# ![kmeans](https://camo.githubusercontent.com/221806df4316920077f52540d452eeb5abeb39d2/68747470733a2f2f75706c6f61642e77696b696d656469612e6f72672f77696b6970656469612f636f6d6d6f6e732f652f65612f4b2d6d65616e735f636f6e76657267656e63652e676966)
